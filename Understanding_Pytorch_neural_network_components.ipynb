# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhana-Tani/PyTorch-basics/blob/main/Understanding_Pytorch_neural_network_components.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''

Breakdown of a simple neural network

X --> input
Wx --> Weights
bx --> bias
A --> Activation function
Y ---> Output

Z = W1.X + b1
Z' = A(Z)
Y = W2.Z' + b2

# Loss function
# Backpropagation
# optimizer
'''
# Out:
# "\n\nBreakdown of a simple neural network\n\nX --> input\nWx --> Weights\nbx --> bias\nA --> Activation function\nY ---> Output\n\nZ = W1.X + b1\nZ' = A(Z)\nY = W2.Z' + b2\n\n# Loss function\n# Backpropagation\n# optimizer\n"

# %% [markdown]
# ## Components of pytorch
#
# - Base class for defining customer models : torch.nn.Module
# - Fully connected (dense) layers : toch.nn.Linear
# - Activation fucntion : torch.nn.ReLU
# - Optimiser : torch.optim
# - Loss function : torch.nn.CrossEntropyLoss
# - Loads data in batch : torch.utils.data.DataLoader

# %% [markdown]
# ## Different ways to create neural network
#
# 1. Function : Flexible, harder to interpret
#
# 2. Sequential : nn.Sequential

# %% [markdown]
# ## Building a neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
## Functional API
class SimpleNN(nn.Module):
  def __init__(self,input_size,hidden_size,output_size):
    super(SimpleNN,self).__init__()
    self.fc1 = nn.Linear(input_size,hidden_size)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(hidden_size,output_size)

  def forward(self,x):
    x=self.fc1(x)
    x=self.relu(x)
    x=self.fc2(x)
    return x

# %%
## Sequential

class SimpleNN(nn.Module):
  def __init__(self,input_size,hidden_size,output_size):
    super(SimpleNN,self).__init__()

    self.network=nn.Sequential(
        nn.Linear(input_size,hidden_size),
        nn.ReLU(),
        nn.Linear(hidden_size,output_size),
    )

  def forward(self,x):
    return self.network(x)

# %% [markdown]
# ## Training the neural network

# %%
model_func=SimpleNN(input_size=4,hidden_size=8,output_size=3)
print(model_func)
# Out:
# SimpleNN(
#   (network): Sequential(
#     (0): Linear(in_features=4, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=3, bias=True)
#   )
# )

# %%
x = torch.randn(10,4)  # 10 samples, 4 feature
y = torch.randint(0,3,(10,))
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_func.parameters(),lr=0.01)

# %%
print(x)
# Out:
# tensor([[ 0.8361,  1.0649,  0.1262,  0.6033],
#         [-0.4208,  0.3731,  1.5823,  0.3836],
#         [ 0.1538,  1.1098, -0.1661,  0.7732],
#         [-0.0399,  0.2994, -0.4273,  0.3845],
#         [ 1.0922, -0.4121,  0.9253,  1.2165],
#         [ 0.1885, -0.9670, -0.9504, -0.7490],
#         [-0.3414,  0.2996,  0.5481, -0.4347],
#         [-2.1970, -0.3882,  1.5512, -0.7444],
#         [ 0.1510,  0.4441,  1.9909, -0.3565],
#         [ 0.8038, -0.1877,  0.5774,  0.0687]])

# %%
print(y)
# Out:
# tensor([1, 0, 2, 1, 2, 2, 2, 0, 0, 0])

# %%
# training loop

epoch=50
for e in range(epoch):
  optimizer.zero_grad()
  outputs = model_func(x)
  loss = criterion(outputs,y)
  loss.backward()
  optimizer.step()

  if (e+1)%10==0:
    print(f'Epoch [{e+1}/{epoch}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/50], Loss: 0.9251
# Epoch [20/50], Loss: 0.8199
# Epoch [30/50], Loss: 0.7175
# Epoch [40/50], Loss: 0.6274
# Epoch [50/50], Loss: 0.5539

# %%
# training loop

epoch=120
for e in range(epoch):
  optimizer.zero_grad()
  outputs = model_func(x)
  loss = criterion(outputs,y)
  loss.backward()
  optimizer.step()

  if (e+1)%10==0:
    print(f'Epoch [{e+1}/{epoch}], Loss: {loss.item():.4f}')
# Out:
# Epoch [10/120], Loss: 0.4922
# Epoch [20/120], Loss: 0.4318
# Epoch [30/120], Loss: 0.3638
# Epoch [40/120], Loss: 0.2995
# Epoch [50/120], Loss: 0.2447
# Epoch [60/120], Loss: 0.1992
# Epoch [70/120], Loss: 0.1617
# Epoch [80/120], Loss: 0.1315
# Epoch [90/120], Loss: 0.1072
# Epoch [100/120], Loss: 0.0881
# Epoch [110/120], Loss: 0.0731
# Epoch [120/120], Loss: 0.0613
